# %%
import pandas as pd
import random

feature_names = ['label','height','weight','shape','appearance','salary','house','car','girlFriend','friend','education','emotion','behavior','cellphone','sick','brain','selfConfidence','interest','GPA','sexmate','responsibility']
data = []
for i in range(1000):
    label = 'loser'
    height = random.randint(150,165)
    weight = random.randint(65,100)
    shape = 'heavy'
    appearance = 'ugly'
    salary = random.randint(0,1000)
    house = 0
    car = 0
    girlFriend = 0
    friend = 'few'
    low_edu = ['highschool' , 'Bachelor']
    education = low_edu[random.randint(0,1)]
    emotion = 'gloomy'
    behavior='passive'
    cellphone='android'
    sick=1
    brain='stupid'
    selfConfidence = random.randint(0,50)
    interest =  random.randint(0,5)
    GPA = round(random.uniform(0,3),2)
    sexmate = 0
    responsibility = 0
    
    item =  [label,height,weight,shape,appearance,salary,house,car,girlFriend,friend,education,emotion,behavior,cellphone,sick,brain,selfConfidence,interest,GPA,sexmate,responsibility]
    data.append(item)

for i in range(1000):
    label = 'winner'
    height = random.randint(165,200)
    weight = random.randint(40,65)
    shape = 'slim'
    appearance = 'handsome'
    salary = random.randint(1001,10000)
    house = random.randint(1,5)
    car = random.randint(1,5)
    girlFriend = random.randint(1,5)
    friend = 'many'
    high_edu = ['Master','Doctor']
    education = high_edu[random.randint(0,1)]
    emotion = 'optimism'
    behavior='positive'
    cellphone='apple'
    sick=0
    brain='smart'
    selfConfidence = random.randint(51,100)
    interest =  random.randint(6,20)
    GPA =  round(random.uniform(3,4.3),2)
    sexmate = random.randint(1,10)
    responsibility = 1
    
    item =  [label,height,weight,shape,appearance,salary,house,car,girlFriend,friend,education,emotion,behavior,cellphone,sick,brain,selfConfidence,interest,GPA,sexmate,responsibility]
    data.append(item)
    
random.shuffle(data)
df = pd.DataFrame(data,columns=feature_names)
print(df)
df.to_csv('data.csv')

'''

Attribute:

height [150~200cm]
weight [40~100kg]
shape [slim heavy]
appearance [handsome ugly]
salary  [0~10000USD]
house [0~5]
car [0~5]
girlFriend [0~5]
friend [few many]
education [highschool Bachelor Master Doctor]
emotion [gloomy optimism]
behavior [positive passive]
cellphone [apple android]
sick [True False]
brain [stupid smart]
selfConfidence [0~100]
interest [0~20]
GPA [0~4.3]
sexmate [0~10]
responsibility [True False]



Rule of Loser:

height <= 165cm
weight >= 70kg
shape:heavy
appearance:ugly
salary <= 1000
house < 1
car < 1
girlFriend < 1
friend:few
education <=Bachelor
emotion:gloomy
behavior:passive
cellphone:android
sick:True
brain:stupid
selfConfidence <=50
Interest <=5
GPA <=3
sexmate < 1
responsibility:False

'''
# Out:
#        label  height  weight  shape appearance  salary  house  car  \
# 0      loser     159      74  heavy       ugly     488      0    0
# 1      loser     163      65  heavy       ugly     450      0    0
# 2     winner     172      65   slim   handsome    4045      3    4
# 3      loser     160      79  heavy       ugly     550      0    0
# 4      loser     163      97  heavy       ugly     600      0    0
# ...      ...     ...     ...    ...        ...     ...    ...  ...
# 1995  winner     173      46   slim   handsome    3594      3    2
# 1996  winner     197      50   slim   handsome    2085      5    2
# 1997  winner     200      64   slim   handsome    7433      1    1
# 1998  winner     185      59   slim   handsome    9210      2    5
# 1999  winner     191      61   slim   handsome    4896      3    4
#
#       girlFriend friend  ...   emotion  behavior cellphone sick   brain  \
# 0              0    few  ...    gloomy   passive   android    1  stupid
# ...

# %%
import pandas as pd
import random

feature_names = ['label','height','weight','shape','appearance','salary','house','car','girlFriend','friend','education','emotion','behavior','cellphone','sick','brain','selfConfidence','interest','GPA','sexmate','responsibility']
data = []
for i in range(1000):
    label = 'loser'
    height = random.randint(150,165)
    weight = random.randint(65,100)
    shape = 'heavy'
    appearance = 'ugly'
    salary = random.randint(0,5000)
    house = random.randint(0,2)
    car = random.randint(0,2)
    girlFriend = random.randint(0,2)
    friend = 'few'
    edu = ['highschool' , 'Bachelor']
    education = edu[random.randint(0,1)]
    emotion = 'gloomy'
    behavior='passive'
    cellphone='android'
    sick=1
    brain='stupid'
    selfConfidence = random.randint(0,70)
    interest =  random.randint(0,12)
    GPA = round(random.uniform(0,4),2)
    sexmate = random.randint(0,4)
    responsibility = 0
    
    item =  [label,height,weight,shape,appearance,salary,house,car,girlFriend,friend,education,emotion,behavior,cellphone,sick,brain,selfConfidence,interest,GPA,sexmate,responsibility]
    data.append(item)

for i in range(1000):
    num = 7
    label = 'winner'
    height = random.randint(150,200)
    weight = random.randint(40,85)
    
    prob = random.randint(0,9)
    shape = 'slim' if prob < num else 'heavy'
    
    prob = random.randint(0,9)
    appearance = 'handsome' if prob < num else 'ugly'
    
    salary = random.randint(1001,10000)
    house = random.randint(1,5)
    car = random.randint(1,5)
    girlFriend = random.randint(1,5)
    
    prob = random.randint(0,9)
    friend = 'many' if prob < num else 'few'
    
    edu = ['Bachelor','Master','Doctor']
    education = edu[random.randint(0,2)]
    
    prob = random.randint(0,9)
    emotion = 'optimism' if prob < num else 'gloomy'
    
    prob = random.randint(0,9)
    behavior='positive' if prob < num else 'passive'
    
    prob = random.randint(0,9)
    cellphone='apple' if prob < num else 'android'
    
    prob = random.randint(0,9)
    sick=0 if prob < num else 1
    
    prob = random.randint(0,9)
    brain='smart' if prob < num else 'stupid'
    
    selfConfidence = random.randint(51,100)
    interest =  random.randint(6,20)
    GPA =  round(random.uniform(3,4.3),2)
    sexmate = random.randint(1,10)
    
    prob = random.randint(0,9)
    responsibility = 1  if prob < num else 0
    
    item =  [label,height,weight,shape,appearance,salary,house,car,girlFriend,friend,education,emotion,behavior,cellphone,sick,brain,selfConfidence,interest,GPA,sexmate,responsibility]
    data.append(item)
    
random.shuffle(data)
df = pd.DataFrame(data,columns=feature_names)
print(df)
df.to_csv('data_r.csv')
# Out:
#        label  height  weight  shape appearance  salary  house  car  \
# 0      loser     151      94  heavy       ugly    1537      0    0
# 1      loser     164      85  heavy       ugly    3984      0    1
# 2      loser     156      85  heavy       ugly    4652      1    1
# 3      loser     158      97  heavy       ugly    4976      0    1
# 4     winner     176      49  heavy       ugly    6335      4    5
# ...      ...     ...     ...    ...        ...     ...    ...  ...
# 1995  winner     153      85   slim   handsome    7173      4    3
# 1996  winner     170      72   slim   handsome    4429      1    3
# 1997   loser     151      74  heavy       ugly     806      0    2
# 1998   loser     158      97  heavy       ugly    2809      2    1
# 1999  winner     185      84   slim   handsome    9704      1    5
#
#       girlFriend friend  ...   emotion  behavior cellphone sick   brain  \
# 0              0    few  ...    gloomy   passive   android    1  stupid
# ...
